# %%
#!pip install bokeh
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fc6f857a-2ad6-43ee-9a91-ae55aa3c4eb8">Loading BokehJS ...</span>
#     </div>

# %%
# !pip install bokeh
# Out:
# Requirement already satisfied: bokeh in c:\users\chandan singh\anaconda3\lib\site-packages (3.6.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\chandan singh\anaconda3\lib\site-packages (from bokeh) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\chandan singh\anaconda3\lib\site-packages (from bokeh) (1.2.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\chandan singh\anaconda3\lib\site-packages (from bokeh) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in c:\users\chandan singh\anaconda3\lib\site-packages (from bokeh) (24.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\chandan singh\anaconda3\lib\site-packages (from bokeh) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\chandan singh\anaconda3\lib\site-packages (from bokeh) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\chandan singh\anaconda3\lib\site-packages (from bokeh) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\chandan singh\anaconda3\lib\site-packages (from bokeh) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\chandan singh\anaconda3\lib\site-packages (from bokeh) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chandan singh\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\chandan singh\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chandan singh\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\chandan singh\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\chandan singh\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.16.0)

# %%
# !pip install bokeh_sampledata
# Out:
# Requirement already satisfied: bokeh_sampledata in c:\users\chandan singh\anaconda3\lib\site-packages (2024.2)
# Requirement already satisfied: icalendar in c:\users\chandan singh\anaconda3\lib\site-packages (from bokeh_sampledata) (6.1.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\chandan singh\anaconda3\lib\site-packages (from bokeh_sampledata) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\chandan singh\anaconda3\lib\site-packages (from pandas>=1.2->bokeh_sampledata) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\chandan singh\anaconda3\lib\site-packages (from pandas>=1.2->bokeh_sampledata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chandan singh\anaconda3\lib\site-packages (from pandas>=1.2->bokeh_sampledata) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\chandan singh\anaconda3\lib\site-packages (from pandas>=1.2->bokeh_sampledata) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\chandan singh\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh_sampledata) (1.16.0)

# %%
from bokeh.sampledata.iris import flowers
from bokeh.plotting import figure, output_file, show

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file("test.html")
p = figure(title = 'test_flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.scatter(flowers['petal_length'], flowers['petal_width']) #circle for scatter plot
show(p)
# Out:
#   <div id="e0ad5ff5-29a7-4547-96e5-8c71a92ff06e" data-root-id="p1464" style="display: contents;"></div>

# %%
output_file("test.html")
p = figure(title = 'test_flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.line(flowers['petal_length'], flowers['petal_width']) #line for line chart
show(p)
# Out:
#   <div id="c35f431b-b462-44e8-8e8c-736075554fa1" data-root-id="p1558" style="display: contents;"></div>

# %%
x = [1, 2, 3, 4]
y = [3, 8, 4, 7]

p = figure(title="line_chart")
p.line(x, y)
show(p)
# Out:
#   <div id="f095bc34-a7be-4a52-89e9-b765a760c7e4" data-root-id="p1606" style="display: contents;"></div>

# %%
x = [1, 2, 3, 4]
y = [3, 8, 4, 7]

p = figure(title="line_chart")
p.scatter(x, y, size = 20, fill_color = 'red', legend_label = "This is my data")
show(p)
# Out:
#   <div id="ec289fbb-e91b-4c85-9f35-f0b33fc8649b" data-root-id="p1650" style="display: contents;"></div>
